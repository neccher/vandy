# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# ## Preprocessing the Data

# %%
# Load the data
file_path = Path('AirQualityAndWeatherDataMerged.csv')
aqi_df = pd.read_csv(file_path)
aqi_df
# Out:
#       Unnamed: 0      state    county            city  date_local  \
# 0              0  Tennessee    Sumner  Hendersonville  2018-01-01
# 1              1  Tennessee  Davidson       Nashville  2018-01-01
# 2              2  Tennessee  Davidson       Nashville  2018-01-02
# 3              3  Tennessee    Sumner  Hendersonville  2018-01-02
# 4              4  Tennessee    Sumner  Hendersonville  2018-01-03
# ...          ...        ...       ...             ...         ...
# 1667        1667  Tennessee  Davidson       Nashville  2020-12-30
# 1668        1668  Tennessee    Sumner  Hendersonville  2020-12-30
# 1669        1669  Tennessee    Sumner  Hendersonville  2020-12-31
# 1670        1670  Tennessee  Davidson       Nashville  2020-12-31
# 1671        1671  Tennessee  Davidson       Nashville  2020-12-31
#
#                      parameter sample_duration             units_of_measure  \
# 0     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 2     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 3     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 4     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# ...                        ...             ...                          ...
# 1667  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1668  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1669  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1670  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1671  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
#
#       arithmetic_mean   aqi  ... Precipitation Snow Snow Depth Wind Speed  \
# 0                 6.2  26.0  ...          0.00  0.0        0.0       13.4
# 1                 5.1  21.0  ...          0.00  0.0        0.0       13.9
# 2                 3.8  16.0  ...          0.00  0.0        0.0        8.8
# 3                 5.6  23.0  ...          0.00  0.0        0.0        7.9
# 4                 5.3  22.0  ...          0.01  0.0        0.0       11.9
# ...               ...   ...  ...           ...  ...        ...        ...
# 1667              8.7  36.0  ...          0.12  0.0        0.0       23.8
# 1668              7.3  30.0  ...          0.25  0.0        0.0       22.1
# 1669              1.0   4.0  ...          0.90  0.0        0.0       16.8
# 1670              2.2   9.0  ...          0.86  0.0        0.0       17.4
# 1671              3.2  13.0  ...          0.86  0.0        0.0       17.4
#
#       Wind Direction  Wind Gust  Visibility  Cloud Cover  Relative Humidity  \
# 0             292.13       19.7         9.9         32.2              58.99
# 1             278.04       21.9         9.9         32.1              57.18
# 2             153.88        NaN         9.9         24.8              50.71
# 3             166.08        NaN         9.9         18.0              52.93
# 4             252.83       24.2         9.9         60.1              50.06
# ...              ...        ...         ...          ...                ...
# 1667          170.63       38.1         9.3         68.3              63.09
# 1668          185.75       36.1         9.3         67.1              64.16
# 1669          127.13       21.8         7.7         97.0              91.89
# 1670          128.83       25.0         7.6         98.8              90.33
# 1671          128.83       25.0         7.6         98.8              90.33
#
#                   Conditions
# 0           Partially cloudy
# 1           Partially cloudy
# 2                      Clear
# 3                      Clear
# 4     Rain, Partially cloudy
# ...                      ...
# 1667  Rain, Partially cloudy
# 1668  Rain, Partially cloudy
# 1669          Rain, Overcast
# 1670          Rain, Overcast
# 1671          Rain, Overcast
#
# [1672 rows x 29 columns]

# %%
aqi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1672 non-null   int64
#  1   state                1672 non-null   object
#  2   county               1672 non-null   object
#  3   city                 1672 non-null   object
#  4   date_local           1672 non-null   object
#  5   parameter            1672 non-null   object
#  6   sample_duration      1672 non-null   object
#  7   units_of_measure     1672 non-null   object
#  8   arithmetic_mean      1672 non-null   float64
#  9   aqi                  1672 non-null   float64
#  10  City                 1672 non-null   object
#  11  State                1672 non-null   object
#  12  Country              1672 non-null   object
#  13  Date time            1672 non-null   object
#  14  Maximum Temperature  1672 non-null   float64
#  15  Minimum Temperature  1672 non-null   float64
#  16  Temperature          1672 non-null   float64
#  17  Wind Chill           791 non-null    float64
#  18  Heat Index           610 non-null    float64
#  19  Precipitation        1672 non-null   float64
#  20  Snow                 1672 non-null   float64
#  21  Snow Depth           1672 non-null   float64
#  22  Wind Speed           1672 non-null   float64
#  23  Wind Direction       1672 non-null   float64
#  24  Wind Gust            1312 non-null   float64
#  25  Visibility           1672 non-null   float64
#  26  Cloud Cover          1672 non-null   float64
#  27  Relative Humidity    1672 non-null   float64
#  28  Conditions           1672 non-null   object
# dtypes: float64(16), int64(1), object(12)
# memory usage: 378.9+ KB

# %%
# Binning aqi values
aqi_bins = [0,50, 100, 300, 500]
group_names = ['Good', 'Moderate', 'Unhealthy', "Hazardous"]

aqi_df["AQI_Range"] = pd.cut(aqi_df["aqi"], aqi_bins, labels=group_names)
aqi_df
# Out:
#       Unnamed: 0      state    county            city  date_local  \
# 0              0  Tennessee    Sumner  Hendersonville  2018-01-01
# 1              1  Tennessee  Davidson       Nashville  2018-01-01
# 2              2  Tennessee  Davidson       Nashville  2018-01-02
# 3              3  Tennessee    Sumner  Hendersonville  2018-01-02
# 4              4  Tennessee    Sumner  Hendersonville  2018-01-03
# ...          ...        ...       ...             ...         ...
# 1667        1667  Tennessee  Davidson       Nashville  2020-12-30
# 1668        1668  Tennessee    Sumner  Hendersonville  2020-12-30
# 1669        1669  Tennessee    Sumner  Hendersonville  2020-12-31
# 1670        1670  Tennessee  Davidson       Nashville  2020-12-31
# 1671        1671  Tennessee  Davidson       Nashville  2020-12-31
#
#                      parameter sample_duration             units_of_measure  \
# 0     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 2     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 3     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 4     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# ...                        ...             ...                          ...
# 1667  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1668  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1669  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1670  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1671  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
#
#       arithmetic_mean   aqi  ... Snow Snow Depth Wind Speed Wind Direction  \
# 0                 6.2  26.0  ...  0.0        0.0       13.4         292.13
# 1                 5.1  21.0  ...  0.0        0.0       13.9         278.04
# 2                 3.8  16.0  ...  0.0        0.0        8.8         153.88
# 3                 5.6  23.0  ...  0.0        0.0        7.9         166.08
# 4                 5.3  22.0  ...  0.0        0.0       11.9         252.83
# ...               ...   ...  ...  ...        ...        ...            ...
# 1667              8.7  36.0  ...  0.0        0.0       23.8         170.63
# 1668              7.3  30.0  ...  0.0        0.0       22.1         185.75
# 1669              1.0   4.0  ...  0.0        0.0       16.8         127.13
# 1670              2.2   9.0  ...  0.0        0.0       17.4         128.83
# 1671              3.2  13.0  ...  0.0        0.0       17.4         128.83
#
#       Wind Gust  Visibility  Cloud Cover  Relative Humidity  \
# 0          19.7         9.9         32.2              58.99
# 1          21.9         9.9         32.1              57.18
# 2           NaN         9.9         24.8              50.71
# 3           NaN         9.9         18.0              52.93
# 4          24.2         9.9         60.1              50.06
# ...         ...         ...          ...                ...
# 1667       38.1         9.3         68.3              63.09
# 1668       36.1         9.3         67.1              64.16
# 1669       21.8         7.7         97.0              91.89
# 1670       25.0         7.6         98.8              90.33
# 1671       25.0         7.6         98.8              90.33
#
#                   Conditions  AQI_Range
# 0           Partially cloudy       Good
# 1           Partially cloudy       Good
# 2                      Clear       Good
# 3                      Clear       Good
# 4     Rain, Partially cloudy       Good
# ...                      ...        ...
# 1667  Rain, Partially cloudy       Good
# 1668  Rain, Partially cloudy       Good
# 1669          Rain, Overcast       Good
# 1670          Rain, Overcast       Good
# 1671          Rain, Overcast       Good
#
# [1672 rows x 30 columns]

# %%
aqi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1672 non-null   int64
#  1   state                1672 non-null   object
#  2   county               1672 non-null   object
#  3   city                 1672 non-null   object
#  4   date_local           1672 non-null   object
#  5   parameter            1672 non-null   object
#  6   sample_duration      1672 non-null   object
#  7   units_of_measure     1672 non-null   object
#  8   arithmetic_mean      1672 non-null   float64
#  9   aqi                  1672 non-null   float64
#  10  City                 1672 non-null   object
#  11  State                1672 non-null   object
#  12  Country              1672 non-null   object
#  13  Date time            1672 non-null   object
#  14  Maximum Temperature  1672 non-null   float64
#  15  Minimum Temperature  1672 non-null   float64
#  16  Temperature          1672 non-null   float64
#  17  Wind Chill           791 non-null    float64
#  18  Heat Index           610 non-null    float64
#  19  Precipitation        1672 non-null   float64
#  20  Snow                 1672 non-null   float64
#  21  Snow Depth           1672 non-null   float64
#  22  Wind Speed           1672 non-null   float64
#  23  Wind Direction       1672 non-null   float64
#  24  Wind Gust            1312 non-null   float64
#  25  Visibility           1672 non-null   float64
#  26  Cloud Cover          1672 non-null   float64
#  27  Relative Humidity    1672 non-null   float64
#  28  Conditions           1672 non-null   object
#  29  AQI_Range            1665 non-null   category
# dtypes: category(1), float64(16), int64(1), object(12)
# memory usage: 380.8+ KB

# %%
aqi_df = aqi_df.drop(["Unnamed: 0", "state", "county", "city", "date_local", "parameter", "sample_duration", "units_of_measure", "City", "State", "Country", "Date time"],axis = 1)
aqi_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-05a219152600> in <module>
# ----> 1 aqi_df = aqi_df.drop(["Unnamed: 0", "state", "county", "city", "date_local", "parameter", "sample_duration", "units_of_measure", "City", "State", "Country", "Date time"],axis = 1)
#       2 aqi_df
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0' 'state' 'county' 'city' 'date_local' 'parameter'\n 'sample_duration' 'units_of_measure' 'City' 'State' 'Country' 'Date time'] not found in axis"

# %%
# Out:
#       arithmetic_mean   aqi  Temperature  Visibility  Cloud Cover  \
# 0                 6.2  26.0         13.3         9.9         32.2
# 1                 5.1  21.0         13.6         9.9         32.1
# 2                 3.8  16.0         14.6         9.9         24.8
# 3                 5.6  23.0         13.9         9.9         18.0
# 4                 5.3  22.0         24.5         9.9         60.1
# ...               ...   ...          ...         ...          ...
# 1667              8.7  36.0         56.0         9.3         68.3
# 1668              7.3  30.0         55.5         9.3         67.1
# 1669              1.0   4.0         41.0         7.7         97.0
# 1670              2.2   9.0         41.6         7.6         98.8
# 1671              3.2  13.0         41.6         7.6         98.8
#
#       Relative Humidity              Conditions AQI_Range
# 0                 58.99        Partially cloudy      Good
# 1                 57.18        Partially cloudy      Good
# 2                 50.71                   Clear      Good
# 3                 52.93                   Clear      Good
# 4                 50.06  Rain, Partially cloudy      Good
# ...                 ...                     ...       ...
# 1667              63.09  Rain, Partially cloudy      Good
# 1668              64.16  Rain, Partially cloudy      Good
# 1669              91.89          Rain, Overcast      Good
# 1670              90.33          Rain, Overcast      Good
# 1671              90.33          Rain, Overcast      Good
#
# [1672 rows x 8 columns]
