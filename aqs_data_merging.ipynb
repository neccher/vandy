# %%
# api
import pandas as pd
from aqs_class import AQSFetcher
import matplotlib.pyplot as plt
from config import aqs_key, aqs_email
# if needed
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import datetime as dt

## reference to https://github.com/bbjornstad/air-pollution-prediction/blob/master/pyaqs.py for the EPA's api function Class

# %%
#init() function
aqs_fetcher = AQSFetcher(aqs_email, aqs_key)

# %%
aqi_pollutant_parameters = aqs_fetcher.get_parameter_list_by_class('AQI POLLUTANTS')
aqi_pollutant_parameters
# Out:
#     code                   parameter_description
# 0  42101                         Carbon monoxide
# 1  42401                          Sulfur dioxide
# 2  42602                  Nitrogen dioxide (NO2)
# 3  44201                                   Ozone
# 4  81102                   PM10 Total 0-10um STP
# 5  88101                PM2.5 - Local Conditions
# 6  88502  Acceptable PM2.5 AQI & Speciation Mass

# %%
pollutant_codes = ['44201', '42101', '88101']
#pollutant_codes = aqi_pollutant_parameters['code'].tolist()
print(pollutant_codes)
# Out:
# ['44201', '42101', '88101']

# %%
o3_code = pollutant_codes[0]
co_code = pollutant_codes[1]
pm_code = pollutant_codes[2]

# %%
state_codes = aqs_fetcher.get_state_codes()

# %%
# to be used in later function
tn_state_code = state_codes.loc[state_codes.state_name == 'Tennessee'].code.values[0]

# %%
#API only allows calling 1 year of data at a time
tn_2018_pollutant_data = aqs_fetcher.daily_data_by_state(tn_state_code, pollutant_codes, 20180101, 20181231)
tn_2018_pollutant_data
# Out:
#       state_code county_code site_number parameter_code  poc   latitude  \
# 0             47         065        4002          88101    2  35.050918
# 1             47         065        4002          88101    2  35.050918
# 2             47         065        4002          88101    2  35.050918
# 3             47         065        4002          88101    2  35.050918
# 4             47         065        4002          88101    2  35.050918
# ...          ...         ...         ...            ...  ...        ...
# 64239         47         165        0007          88101    1  36.297560
# 64240         47         165        0007          88101    1  36.297560
# 64241         47         165        0007          88101    1  36.297560
# 64242         47         165        0007          88101    1  36.297560
# 64243         47         165        0007          88101    1  36.297560
#
#        longitude  datum                 parameter sample_duration  \
# 0     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# 1     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# 2     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# 3     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# 4     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# ...          ...    ...                       ...             ...
# 64239 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
# 64240 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
# 64241 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
# 64242 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
# 64243 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
#
#       pollutant_standard  date_local             units_of_measure event_type  \
# 0       PM25 Annual 2012  2018-01-02  Micrograms/cubic meter (LC)       None
# 1       PM25 Annual 2012  2018-01-11  Micrograms/cubic meter (LC)       None
# 2       PM25 Annual 2012  2018-01-14  Micrograms/cubic meter (LC)       None
# 3       PM25 Annual 2012  2018-01-17  Micrograms/cubic meter (LC)       None
# 4       PM25 Annual 2012  2018-01-20  Micrograms/cubic meter (LC)       None
# ...                  ...         ...                          ...        ...
# 64239  PM25 24-hour 2006  2018-12-19  Micrograms/cubic meter (LC)       None
# 64240  PM25 24-hour 2006  2018-12-22  Micrograms/cubic meter (LC)       None
# 64241  PM25 24-hour 2006  2018-12-25  Micrograms/cubic meter (LC)       None
# 64242  PM25 24-hour 2006  2018-12-28  Micrograms/cubic meter (LC)       None
# 64243  PM25 24-hour 2006  2018-12-31  Micrograms/cubic meter (LC)       None
#
#        observation_count  observation_percent validity_indicator  \
# 0                      1                100.0                  Y
# 1                      1                100.0                  Y
# 2                      1                100.0                  Y
# 3                      1                100.0                  Y
# 4                      1                100.0                  Y
# ...                  ...                  ...                ...
# 64239                  1                100.0                  Y
# 64240                  1                100.0                  Y
# 64241                  1                100.0                  Y
# 64242                  1                100.0                  Y
# 64243                  1                100.0                  Y
#
#        arithmetic_mean  first_max_value  first_max_hour   aqi method_code  \
# 0                  7.2              7.2               0  30.0         145
# 1                  5.5              5.5               0  23.0         145
# 2                  5.7              5.7               0  24.0         145
# 3                 10.1             10.1               0  42.0         145
# 4                 13.7             13.7               0  54.0         145
# ...                ...              ...             ...   ...         ...
# 64239              8.9              8.9               0  37.0         118
# 64240              7.1              7.1               0  30.0         118
# 64241              6.9              6.9               0  29.0         118
# 64242              2.4              2.4               0  10.0         118
# 64243              2.6              2.6               0  11.0         118
#
#                                                   method  \
# 0      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 1      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 2      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 3      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 4      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# ...                                                  ...
# 64239  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 64240  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 64241  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 64242  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 64243  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
#
#                                     local_site_name  \
# 0                                      Siskin Drive
# 1                                      Siskin Drive
# 2                                      Siskin Drive
# 3                                      Siskin Drive
# 4                                      Siskin Drive
# ...                                             ...
# 64239  Hendersonville Ozone Site at Old Hickory Dam
# 64240  Hendersonville Ozone Site at Old Hickory Dam
# 64241  Hendersonville Ozone Site at Old Hickory Dam
# 64242  Hendersonville Ozone Site at Old Hickory Dam
# 64243  Hendersonville Ozone Site at Old Hickory Dam
#
#                                             site_address      state    county  \
# 0                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# 1                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# 2                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# 3                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# 4                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# ...                                                  ...        ...       ...
# 64239  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
# 64240  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
# 64241  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
# 64242  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
# 64243  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
#
#                  city cbsa_code  \
# 0         Chattanooga     16860
# 1         Chattanooga     16860
# 2         Chattanooga     16860
# 3         Chattanooga     16860
# 4         Chattanooga     16860
# ...               ...       ...
# 64239  Hendersonville     34980
# 64240  Hendersonville     34980
# 64241  Hendersonville     34980
# 64242  Hendersonville     34980
# 64243  Hendersonville     34980
#
#                                                  cbsa date_of_last_change
# 0                                  Chattanooga, TN-GA          2020-03-17
# 1                                  Chattanooga, TN-GA          2020-03-17
# 2                                  Chattanooga, TN-GA          2020-03-17
# 3                                  Chattanooga, TN-GA          2020-03-17
# 4                                  Chattanooga, TN-GA          2020-03-17
# ...                                               ...                 ...
# 64239  Nashville-Davidson--Murfreesboro--Franklin, TN          2020-08-13
# 64240  Nashville-Davidson--Murfreesboro--Franklin, TN          2020-08-13
# 64241  Nashville-Davidson--Murfreesboro--Franklin, TN          2020-08-13
# 64242  Nashville-Davidson--Murfreesboro--Franklin, TN          2020-08-13
# 64243  Nashville-Davidson--Murfreesboro--Franklin, TN          2020-08-13
#
# [64244 rows x 31 columns]

# %%
tn_2019_pollutant_data = aqs_fetcher.daily_data_by_state(tn_state_code, pollutant_codes, 20190101, 20191231)
tn_2019_pollutant_data
# Out:
#       state_code county_code site_number parameter_code  poc  latitude  \
# 0             47         165        0007          88101    1  36.29756
# 1             47         165        0007          88101    1  36.29756
# 2             47         165        0007          88101    1  36.29756
# 3             47         165        0007          88101    1  36.29756
# 4             47         165        0007          88101    1  36.29756
# ...          ...         ...         ...            ...  ...       ...
# 66144         47         009        0101          42101    1  35.63348
# 66145         47         009        0101          42101    1  35.63348
# 66146         47         009        0101          42101    1  35.63348
# 66147         47         009        0101          42101    1  35.63348
# 66148         47         009        0101          42101    1  35.63348
#
#        longitude  datum                 parameter        sample_duration  \
# 0     -86.653137  WGS84  PM2.5 - Local Conditions                24 HOUR
# 1     -86.653137  WGS84  PM2.5 - Local Conditions                24 HOUR
# 2     -86.653137  WGS84  PM2.5 - Local Conditions                24 HOUR
# 3     -86.653137  WGS84  PM2.5 - Local Conditions                24 HOUR
# 4     -86.653137  WGS84  PM2.5 - Local Conditions                24 HOUR
# ...          ...    ...                       ...                    ...
# 66144 -83.941606  WGS84           Carbon monoxide  8-HR RUN AVG END HOUR
# 66145 -83.941606  WGS84           Carbon monoxide                 1 HOUR
# 66146 -83.941606  WGS84           Carbon monoxide  8-HR RUN AVG END HOUR
# 66147 -83.941606  WGS84           Carbon monoxide                 1 HOUR
# 66148 -83.941606  WGS84           Carbon monoxide  8-HR RUN AVG END HOUR
#
#       pollutant_standard  date_local             units_of_measure event_type  \
# 0      PM25 24-hour 2006  2019-01-03  Micrograms/cubic meter (LC)       None
# 1       PM25 Annual 2006  2019-01-03  Micrograms/cubic meter (LC)       None
# 2      PM25 24-hour 2012  2019-01-03  Micrograms/cubic meter (LC)       None
# 3       PM25 Annual 2012  2019-01-03  Micrograms/cubic meter (LC)       None
# 4      PM25 24-hour 2006  2019-01-06  Micrograms/cubic meter (LC)       None
# ...                  ...         ...                          ...        ...
# 66144     CO 8-hour 1971  2019-12-29            Parts per million       None
# 66145     CO 1-hour 1971  2019-12-30            Parts per million       None
# 66146     CO 8-hour 1971  2019-12-30            Parts per million       None
# 66147     CO 1-hour 1971  2019-12-31            Parts per million       None
# 66148     CO 8-hour 1971  2019-12-31            Parts per million       None
#
#        observation_count  observation_percent validity_indicator  \
# 0                      1                100.0                  Y
# 1                      1                100.0                  Y
# 2                      1                100.0                  Y
# 3                      1                100.0                  Y
# 4                      1                100.0                  Y
# ...                  ...                  ...                ...
# 66144                 22                 92.0                  Y
# 66145                 21                 88.0                  Y
# 66146                 24                100.0                  Y
# 66147                 21                 88.0                  Y
# 66148                 18                 75.0                  Y
#
#        arithmetic_mean  first_max_value  first_max_hour   aqi method_code  \
# 0            13.000000           13.000               0  53.0         118
# 1            13.000000           13.000               0  53.0         118
# 2            13.000000           13.000               0  53.0         118
# 3            13.000000           13.000               0  53.0         118
# 4             7.900000            7.900               0  33.0         118
# ...                ...              ...             ...   ...         ...
# 66144         0.100000            0.100               0   1.0         554
# 66145         0.113476            0.124              23   NaN         554
# 66146         0.100000            0.100               0   1.0         554
# 66147         0.123286            0.136              17   NaN         554
# 66148         0.100000            0.100               0   1.0         554
#
#                                                   method  \
# 0      R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 1      R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 2      R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 3      R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 4      R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# ...                                                  ...
# 66144  INSTRUMENTAL - Gas Filter Correlation Thermo E...
# 66145  INSTRUMENTAL - Gas Filter Correlation Thermo E...
# 66146  INSTRUMENTAL - Gas Filter Correlation Thermo E...
# 66147  INSTRUMENTAL - Gas Filter Correlation Thermo E...
# 66148  INSTRUMENTAL - Gas Filter Correlation Thermo E...
#
#                                     local_site_name  \
# 0      Hendersonville Ozone Site at Old Hickory Dam
# 1      Hendersonville Ozone Site at Old Hickory Dam
# 2      Hendersonville Ozone Site at Old Hickory Dam
# 3      Hendersonville Ozone Site at Old Hickory Dam
# 4      Hendersonville Ozone Site at Old Hickory Dam
# ...                                             ...
# 66144          Great Smoky Mountains NP - Look Rock
# 66145          Great Smoky Mountains NP - Look Rock
# 66146          Great Smoky Mountains NP - Look Rock
# 66147          Great Smoky Mountains NP - Look Rock
# 66148          Great Smoky Mountains NP - Look Rock
#
#                                             site_address      state  county  \
# 0      ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee  Sumner
# 1      ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee  Sumner
# 2      ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee  Sumner
# 3      ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee  Sumner
# 4      ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee  Sumner
# ...                                                  ...        ...     ...
# 66144                 GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee  Blount
# 66145                 GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee  Blount
# 66146                 GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee  Blount
# 66147                 GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee  Blount
# 66148                 GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee  Blount
#
#                  city cbsa_code  \
# 0      Hendersonville     34980
# 1      Hendersonville     34980
# 2      Hendersonville     34980
# 3      Hendersonville     34980
# 4      Hendersonville     34980
# ...               ...       ...
# 66144   Not in a city     28940
# 66145   Not in a city     28940
# 66146   Not in a city     28940
# 66147   Not in a city     28940
# 66148   Not in a city     28940
#
#                                                  cbsa date_of_last_change
# 0      Nashville-Davidson--Murfreesboro--Franklin, TN          2020-04-01
# 1      Nashville-Davidson--Murfreesboro--Franklin, TN          2020-04-01
# 2      Nashville-Davidson--Murfreesboro--Franklin, TN          2020-04-01
# 3      Nashville-Davidson--Murfreesboro--Franklin, TN          2020-04-01
# 4      Nashville-Davidson--Murfreesboro--Franklin, TN          2020-04-01
# ...                                               ...                 ...
# 66144                                   Knoxville, TN          2020-02-26
# 66145                                   Knoxville, TN          2020-02-26
# 66146                                   Knoxville, TN          2020-02-26
# 66147                                   Knoxville, TN          2020-02-26
# 66148                                   Knoxville, TN          2020-02-26
#
# [66149 rows x 31 columns]

# %%
tn_2020_pollutant_data = aqs_fetcher.daily_data_by_state(tn_state_code, pollutant_codes, 20200101, 20201231)
tn_2020_pollutant_data
# Out:
#       state_code county_code site_number parameter_code  poc   latitude  \
# 0             47         065        4002          88101    2  35.050918
# 1             47         065        4002          88101    2  35.050918
# 2             47         065        4002          88101    2  35.050918
# 3             47         065        4002          88101    2  35.050918
# 4             47         065        4002          88101    2  35.050918
# ...          ...         ...         ...            ...  ...        ...
# 67790         47         165        0007          88101    1  36.297560
# 67791         47         165        0007          88101    1  36.297560
# 67792         47         165        0007          88101    1  36.297560
# 67793         47         165        0007          88101    1  36.297560
# 67794         47         165        0007          88101    1  36.297560
#
#        longitude  datum                 parameter sample_duration  \
# 0     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# 1     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# 2     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# 3     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# 4     -85.293019  WGS84  PM2.5 - Local Conditions         24 HOUR
# ...          ...    ...                       ...             ...
# 67790 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
# 67791 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
# 67792 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
# 67793 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
# 67794 -86.653137  WGS84  PM2.5 - Local Conditions         24 HOUR
#
#       pollutant_standard  date_local             units_of_measure event_type  \
# 0       PM25 Annual 2012  2020-12-29  Micrograms/cubic meter (LC)       None
# 1      PM25 24-hour 2012  2020-12-29  Micrograms/cubic meter (LC)       None
# 2       PM25 Annual 2006  2020-12-29  Micrograms/cubic meter (LC)       None
# 3      PM25 24-hour 2006  2020-12-29  Micrograms/cubic meter (LC)       None
# 4       PM25 Annual 2012  2020-12-17  Micrograms/cubic meter (LC)       None
# ...                  ...         ...                          ...        ...
# 67790  PM25 24-hour 2006  2020-01-04  Micrograms/cubic meter (LC)       None
# 67791   PM25 Annual 2012  2020-01-01  Micrograms/cubic meter (LC)       None
# 67792  PM25 24-hour 2012  2020-01-01  Micrograms/cubic meter (LC)       None
# 67793   PM25 Annual 2006  2020-01-01  Micrograms/cubic meter (LC)       None
# 67794  PM25 24-hour 2006  2020-01-01  Micrograms/cubic meter (LC)       None
#
#        observation_count  observation_percent validity_indicator  \
# 0                      1                100.0                  Y
# 1                      1                100.0                  Y
# 2                      1                100.0                  Y
# 3                      1                100.0                  Y
# 4                      1                100.0                  Y
# ...                  ...                  ...                ...
# 67790                  1                100.0                  Y
# 67791                  1                100.0                  Y
# 67792                  1                100.0                  Y
# 67793                  1                100.0                  Y
# 67794                  1                100.0                  Y
#
#        arithmetic_mean  first_max_value  first_max_hour   aqi method_code  \
# 0                 13.4             13.4               0  54.0         145
# 1                 13.4             13.4               0  54.0         145
# 2                 13.4             13.4               0  54.0         145
# 3                 13.4             13.4               0  54.0         145
# 4                  7.5              7.5               0  31.0         145
# ...                ...              ...             ...   ...         ...
# 67790              6.0              6.0               0  25.0         118
# 67791              4.8              4.8               0  20.0         118
# 67792              4.8              4.8               0  20.0         118
# 67793              4.8              4.8               0  20.0         118
# 67794              4.8              4.8               0  20.0         118
#
#                                                   method  \
# 0      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 1      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 2      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 3      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 4      R & P Model 2025 PM-2.5 Sequential Air Sampler...
# ...                                                  ...
# 67790  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 67791  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 67792  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 67793  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
# 67794  R & P Model 2025 PM2.5 Sequential w/WINS - GRA...
#
#                                     local_site_name  \
# 0                                      Siskin Drive
# 1                                      Siskin Drive
# 2                                      Siskin Drive
# 3                                      Siskin Drive
# 4                                      Siskin Drive
# ...                                             ...
# 67790  Hendersonville Ozone Site at Old Hickory Dam
# 67791  Hendersonville Ozone Site at Old Hickory Dam
# 67792  Hendersonville Ozone Site at Old Hickory Dam
# 67793  Hendersonville Ozone Site at Old Hickory Dam
# 67794  Hendersonville Ozone Site at Old Hickory Dam
#
#                                             site_address      state    county  \
# 0                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# 1                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# 2                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# 3                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# 4                    RIVERSIDE SUBSTATION  911 SISKIN DR  Tennessee  Hamilton
# ...                                                  ...        ...       ...
# 67790  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
# 67791  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
# 67792  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
# 67793  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
# 67794  ROCKLAND RECREATION AREA-OLD HICKORY DAM Army ...  Tennessee    Sumner
#
#                  city cbsa_code  \
# 0         Chattanooga     16860
# 1         Chattanooga     16860
# 2         Chattanooga     16860
# 3         Chattanooga     16860
# 4         Chattanooga     16860
# ...               ...       ...
# 67790  Hendersonville     34980
# 67791  Hendersonville     34980
# 67792  Hendersonville     34980
# 67793  Hendersonville     34980
# 67794  Hendersonville     34980
#
#                                                  cbsa date_of_last_change
# 0                                  Chattanooga, TN-GA          2021-02-11
# 1                                  Chattanooga, TN-GA          2021-02-11
# 2                                  Chattanooga, TN-GA          2021-02-11
# 3                                  Chattanooga, TN-GA          2021-02-11
# 4                                  Chattanooga, TN-GA          2021-02-11
# ...                                               ...                 ...
# 67790  Nashville-Davidson--Murfreesboro--Franklin, TN          2021-03-05
# 67791  Nashville-Davidson--Murfreesboro--Franklin, TN          2021-03-05
# 67792  Nashville-Davidson--Murfreesboro--Franklin, TN          2021-03-05
# 67793  Nashville-Davidson--Murfreesboro--Franklin, TN          2021-03-05
# 67794  Nashville-Davidson--Murfreesboro--Franklin, TN          2021-03-05
#
# [67795 rows x 31 columns]

# %%
# combining years
step1 = tn_2018_pollutant_data.append(tn_2019_pollutant_data, ignore_index=True)

# %%
#combining to 1 df for 2018-2020 data
combined_df = step1.append(tn_2020_pollutant_data, ignore_index = True)

# %%
clean_features = [ 'date_local', 'parameter', 'sample_duration', 'units_of_measure', 'arithmetic_mean', 'aqi',]
combined_df = combined_df.loc[combined_df['validity_indicator']=='Y']

# %%
#Adding Location information too
clean_features_locations = [ 'state', 'county', 'city', 'date_local', 'parameter', 'sample_duration', 'units_of_measure', 'arithmetic_mean', 'aqi',]
combined_locations_df = combined_df.loc[combined_df['validity_indicator']=='Y']

# %%
# only middle TN
combined_df = combined_df.loc[combined_df['cbsa_code']=='34980']

# %%
# only middle TN For Location df
#combined_locations_df = combined_locations_df.loc[combined_df['cbsa_code']=='34980']

# %%
#Just want average
combined_locations_df = combined_locations_df.loc[combined_locations_df['sample_duration']=='24-HR BLK AVG']

# %%
# using only important features
clean_df = combined_df[clean_features]
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39302 entries, 468 to 198187
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_local        39302 non-null  object
#  1   parameter         39302 non-null  object
#  2   sample_duration   39302 non-null  object
#  3   units_of_measure  39302 non-null  object
#  4   arithmetic_mean   39302 non-null  float64
#  5   aqi               31184 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 3.3+ MB

# %%
# using only important features
clean_locations_df = combined_locations_df[clean_features_locations]
clean_locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75576 entries, 468 to 174476
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             75576 non-null  object
#  1   county            75576 non-null  object
#  2   city              75576 non-null  object
#  3   date_local        75576 non-null  object
#  4   parameter         75576 non-null  object
#  5   sample_duration   75576 non-null  object
#  6   units_of_measure  75576 non-null  object
#  7   arithmetic_mean   75576 non-null  float64
#  8   aqi               75576 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 5.8+ MB

# %%
#drop null rows
clean_df = clean_df.dropna()
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31184 entries, 468 to 198187
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_local        31184 non-null  object
#  1   parameter         31184 non-null  object
#  2   sample_duration   31184 non-null  object
#  3   units_of_measure  31184 non-null  object
#  4   arithmetic_mean   31184 non-null  float64
#  5   aqi               31184 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 1.7+ MB

# %%
#drop null rows
clean_locations_df = clean_locations_df.dropna()
clean_locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75576 entries, 468 to 174476
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             75576 non-null  object
#  1   county            75576 non-null  object
#  2   city              75576 non-null  object
#  3   date_local        75576 non-null  object
#  4   parameter         75576 non-null  object
#  5   sample_duration   75576 non-null  object
#  6   units_of_measure  75576 non-null  object
#  7   arithmetic_mean   75576 non-null  float64
#  8   aqi               75576 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 5.8+ MB

# %%
clean_df['parameter'].value_counts()
# Out:
# PM2.5 - Local Conditions    19502
# Ozone                       10605
# Carbon monoxide              1077
# Name: parameter, dtype: int64

# %%
# saving large file
#output_data_file = "./data/total_pollution_data2018_2020.csv"
#clean_df.to_csv(output_data_file, index=False)

# %%
clean_df.columns
# Out:
# Index(['date_local', 'parameter', 'sample_duration', 'units_of_measure',
#        'arithmetic_mean', 'aqi'],
#       dtype='object')

# %%
# grouping data by date and averaging parameters
group_df = clean_df.groupby(['date_local', 'parameter']).agg({'arithmetic_mean': 'mean', 'aqi': 'mean'}).reset_index()
group_df['parameter'].value_counts()
# Out:
# PM2.5 - Local Conditions    1096
# Carbon monoxide             1077
# Ozone                        747
# Name: parameter, dtype: int64

# %%
# grouping location data by date and averaging parameters
group_locations_df = clean_locations_df.groupby(['date_local', 'city', 'parameter']).agg({'arithmetic_mean': 'mean', 'aqi': 'mean'}).reset_index()
group_locations_df['parameter'].value_counts()
# Out:
# PM2.5 - Local Conditions    16576
# Name: parameter, dtype: int64

# %%
#making new DF for eatch pollutant in case we want to do machine learning by pollutant
co_df = group_df.loc[group_df['parameter']=='Carbon monoxide']
pm_df = group_df.loc[group_df['parameter']=='PM2.5 - Local Conditions']
o3_df = group_df.loc[group_df['parameter']=='Ozone']

# %%
#Pollutant DFs with location info
co_locations_df = group_locations_df.loc[group_locations_df['parameter']=='Carbon monoxide']
pm_locations_df = group_locations_df.loc[group_locations_df['parameter']=='PM2.5 - Local Conditions']
o3_locations_df = group_locations_df.loc[group_locations_df['parameter']=='Ozone']

# %%
# clean_data_file = "./data/clean_data2018_2020.csv"
# co_data_file = "./data/co_data2018_2020.csv"
# pm_data_file = "./data/pm_data2018_2020.csv"
# o3_data_file = "./data/o3_data2018_2020.csv"

# clean_df.to_csv(clean_data_file, index=False)
# co_df.to_csv(co_data_file, index=False)
# pm_df.to_csv(pm_data_file, index=False)
# o3_df.to_csv(o3_data_file, index=False)

# %%
group_df.dtypes
# Out:
# date_local          object
# parameter           object
# arithmetic_mean    float64
# aqi                float64
# dtype: object

# %%
#Viewing sample of dataframe
clean_locations_df.head(50)
# Out:
#          state county      city  date_local                 parameter  \
# 468  Tennessee  Maury  Columbia  2018-01-01  PM2.5 - Local Conditions
# 469  Tennessee  Maury  Columbia  2018-01-02  PM2.5 - Local Conditions
# 470  Tennessee  Maury  Columbia  2018-01-03  PM2.5 - Local Conditions
# 471  Tennessee  Maury  Columbia  2018-01-04  PM2.5 - Local Conditions
# 472  Tennessee  Maury  Columbia  2018-01-05  PM2.5 - Local Conditions
# 473  Tennessee  Maury  Columbia  2018-01-06  PM2.5 - Local Conditions
# 474  Tennessee  Maury  Columbia  2018-01-07  PM2.5 - Local Conditions
# 475  Tennessee  Maury  Columbia  2018-01-08  PM2.5 - Local Conditions
# 476  Tennessee  Maury  Columbia  2018-01-09  PM2.5 - Local Conditions
# 477  Tennessee  Maury  Columbia  2018-01-10  PM2.5 - Local Conditions
# 478  Tennessee  Maury  Columbia  2018-01-11  PM2.5 - Local Conditions
# 479  Tennessee  Maury  Columbia  2018-01-12  PM2.5 - Local Conditions
# 480  Tennessee  Maury  Columbia  2018-01-13  PM2.5 - Local Conditions
# 481  Tennessee  Maury  Columbia  2018-01-14  PM2.5 - Local Conditions
# 482  Tennessee  Maury  Columbia  2018-01-15  PM2.5 - Local Conditions
# 483  Tennessee  Maury  Columbia  2018-01-16  PM2.5 - Local Conditions
# 484  Tennessee  Maury  Columbia  2018-01-17  PM2.5 - Local Conditions
# 485  Tennessee  Maury  Columbia  2018-01-18  PM2.5 - Local Conditions
# 486  Tennessee  Maury  Columbia  2018-01-19  PM2.5 - Local Conditions
# 487  Tennessee  Maury  Columbia  2018-01-20  PM2.5 - Local Conditions
# 488  Tennessee  Maury  Columbia  2018-01-21  PM2.5 - Local Conditions
# 489  Tennessee  Maury  Columbia  2018-01-22  PM2.5 - Local Conditions
# 490  Tennessee  Maury  Columbia  2018-01-23  PM2.5 - Local Conditions
# 491  Tennessee  Maury  Columbia  2018-01-24  PM2.5 - Local Conditions
# 492  Tennessee  Maury  Columbia  2018-01-25  PM2.5 - Local Conditions
# 493  Tennessee  Maury  Columbia  2018-01-26  PM2.5 - Local Conditions
# 494  Tennessee  Maury  Columbia  2018-01-27  PM2.5 - Local Conditions
# 495  Tennessee  Maury  Columbia  2018-01-28  PM2.5 - Local Conditions
# 496  Tennessee  Maury  Columbia  2018-01-29  PM2.5 - Local Conditions
# 497  Tennessee  Maury  Columbia  2018-01-30  PM2.5 - Local Conditions
# 498  Tennessee  Maury  Columbia  2018-02-01  PM2.5 - Local Conditions
# 499  Tennessee  Maury  Columbia  2018-02-02  PM2.5 - Local Conditions
# 500  Tennessee  Maury  Columbia  2018-02-03  PM2.5 - Local Conditions
# 501  Tennessee  Maury  Columbia  2018-02-04  PM2.5 - Local Conditions
# 502  Tennessee  Maury  Columbia  2018-02-05  PM2.5 - Local Conditions
# 503  Tennessee  Maury  Columbia  2018-02-06  PM2.5 - Local Conditions
# 504  Tennessee  Maury  Columbia  2018-02-07  PM2.5 - Local Conditions
# 505  Tennessee  Maury  Columbia  2018-02-08  PM2.5 - Local Conditions
# 506  Tennessee  Maury  Columbia  2018-02-09  PM2.5 - Local Conditions
# 507  Tennessee  Maury  Columbia  2018-02-10  PM2.5 - Local Conditions
# 508  Tennessee  Maury  Columbia  2018-02-11  PM2.5 - Local Conditions
# 509  Tennessee  Maury  Columbia  2018-02-12  PM2.5 - Local Conditions
# 510  Tennessee  Maury  Columbia  2018-02-13  PM2.5 - Local Conditions
# 511  Tennessee  Maury  Columbia  2018-02-14  PM2.5 - Local Conditions
# 512  Tennessee  Maury  Columbia  2018-02-15  PM2.5 - Local Conditions
# 513  Tennessee  Maury  Columbia  2018-02-16  PM2.5 - Local Conditions
# 514  Tennessee  Maury  Columbia  2018-02-17  PM2.5 - Local Conditions
# 515  Tennessee  Maury  Columbia  2018-02-18  PM2.5 - Local Conditions
# 516  Tennessee  Maury  Columbia  2018-02-19  PM2.5 - Local Conditions
# 517  Tennessee  Maury  Columbia  2018-02-20  PM2.5 - Local Conditions
#
#     sample_duration             units_of_measure  arithmetic_mean   aqi
# 468   24-HR BLK AVG  Micrograms/cubic meter (LC)              5.9  25.0
# 469   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.3  30.0
# 470   24-HR BLK AVG  Micrograms/cubic meter (LC)              6.0  25.0
# 471   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.6  32.0
# 472   24-HR BLK AVG  Micrograms/cubic meter (LC)              9.1  38.0
# 473   24-HR BLK AVG  Micrograms/cubic meter (LC)              9.8  41.0
# 474   24-HR BLK AVG  Micrograms/cubic meter (LC)             10.7  45.0
# 475   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.7  32.0
# 476   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.8  33.0
# 477   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.4  18.0
# 478   24-HR BLK AVG  Micrograms/cubic meter (LC)              3.1  13.0
# 479   24-HR BLK AVG  Micrograms/cubic meter (LC)              2.3  10.0
# 480   24-HR BLK AVG  Micrograms/cubic meter (LC)              3.3  14.0
# 481   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.5  19.0
# 482   24-HR BLK AVG  Micrograms/cubic meter (LC)              5.7  24.0
# 483   24-HR BLK AVG  Micrograms/cubic meter (LC)              5.4  23.0
# 484   24-HR BLK AVG  Micrograms/cubic meter (LC)              8.9  37.0
# 485   24-HR BLK AVG  Micrograms/cubic meter (LC)              8.4  35.0
# 486   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.6  32.0
# 487   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.8  20.0
# 488   24-HR BLK AVG  Micrograms/cubic meter (LC)              5.3  22.0
# 489   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.1  30.0
# 490   24-HR BLK AVG  Micrograms/cubic meter (LC)              2.4  10.0
# 491   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.8  20.0
# 492   24-HR BLK AVG  Micrograms/cubic meter (LC)              5.8  24.0
# 493   24-HR BLK AVG  Micrograms/cubic meter (LC)              9.9  41.0
# 494   24-HR BLK AVG  Micrograms/cubic meter (LC)              9.5  40.0
# 495   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.5  19.0
# 496   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.9  20.0
# 497   24-HR BLK AVG  Micrograms/cubic meter (LC)              6.7  28.0
# 498   24-HR BLK AVG  Micrograms/cubic meter (LC)              6.0  25.0
# 499   24-HR BLK AVG  Micrograms/cubic meter (LC)              2.9  12.0
# 500   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.7  20.0
# 501   24-HR BLK AVG  Micrograms/cubic meter (LC)             10.0  42.0
# 502   24-HR BLK AVG  Micrograms/cubic meter (LC)              6.3  26.0
# 503   24-HR BLK AVG  Micrograms/cubic meter (LC)             10.3  43.0
# 504   24-HR BLK AVG  Micrograms/cubic meter (LC)              9.6  40.0
# 505   24-HR BLK AVG  Micrograms/cubic meter (LC)             11.2  47.0
# 506   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.9  33.0
# 507   24-HR BLK AVG  Micrograms/cubic meter (LC)              3.7  15.0
# 508   24-HR BLK AVG  Micrograms/cubic meter (LC)              2.7  11.0
# 509   24-HR BLK AVG  Micrograms/cubic meter (LC)              9.6  40.0
# 510   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.8  33.0
# 511   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.1  17.0
# 512   24-HR BLK AVG  Micrograms/cubic meter (LC)              6.8  28.0
# 513   24-HR BLK AVG  Micrograms/cubic meter (LC)              8.3  35.0
# 514   24-HR BLK AVG  Micrograms/cubic meter (LC)              8.5  35.0
# 515   24-HR BLK AVG  Micrograms/cubic meter (LC)              4.5  19.0
# 516   24-HR BLK AVG  Micrograms/cubic meter (LC)              6.6  28.0
# 517   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.6  32.0

# %%
#Changing date_local to datetime then back to string to join tables
clean_locations_df['date_local'] = pd.to_datetime(clean_locations_df['date_local'])
clean_locations_df['date_local'] = clean_locations_df['date_local'].dt.strftime('%Y-%m-%d')
clean_locations_df.head()
# Out:
#          state county      city  date_local                 parameter  \
# 468  Tennessee  Maury  Columbia  2018-01-01  PM2.5 - Local Conditions
# 469  Tennessee  Maury  Columbia  2018-01-02  PM2.5 - Local Conditions
# 470  Tennessee  Maury  Columbia  2018-01-03  PM2.5 - Local Conditions
# 471  Tennessee  Maury  Columbia  2018-01-04  PM2.5 - Local Conditions
# 472  Tennessee  Maury  Columbia  2018-01-05  PM2.5 - Local Conditions
#
#     sample_duration             units_of_measure  arithmetic_mean   aqi
# 468   24-HR BLK AVG  Micrograms/cubic meter (LC)              5.9  25.0
# 469   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.3  30.0
# 470   24-HR BLK AVG  Micrograms/cubic meter (LC)              6.0  25.0
# 471   24-HR BLK AVG  Micrograms/cubic meter (LC)              7.6  32.0
# 472   24-HR BLK AVG  Micrograms/cubic meter (LC)              9.1  38.0

# %%
#Dropping Duplicates to keep info for one day
clean_locations_nodups_df = clean_locations_df.drop_duplicates()
#ordering by oldest date first
clean_locations_nodups_df = clean_locations_nodups_df.sort_values(by=['date_local'])
clean_locations_nodups_df.head(50)
# Out:
#            state      county            city  date_local  \
# 468    Tennessee       Maury        Columbia  2018-01-01
# 32986  Tennessee      Loudon          Loudon  2018-01-01
# 17546  Tennessee      Blount       Maryville  2018-01-01
# 13989  Tennessee    Sullivan       Kingsport  2018-01-01
# 37391  Tennessee      McMinn          Athens  2018-01-01
# 19348  Tennessee    Hamilton     Chattanooga  2018-01-01
# 10543  Tennessee  Montgomery     Clarksville  2018-01-01
# 31443  Tennessee    Davidson       Nashville  2018-01-01
# 12315  Tennessee      Sumner  Hendersonville  2018-01-01
# 22542  Tennessee       Roane        Harriman  2018-01-01
# 34783  Tennessee      Loudon          Loudon  2018-01-01
# 2138   Tennessee        Dyer       Dyersburg  2018-01-01
# 24801  Tennessee      Putnam      Cookeville  2018-01-01
# 29331  Tennessee        Knox       Knoxville  2018-01-01
# 26567  Tennessee     Madison         Jackson  2018-01-01
# 15777  Tennessee    Lawrence         Loretto  2018-01-01
# 2139   Tennessee        Dyer       Dyersburg  2018-01-02
# 22543  Tennessee       Roane        Harriman  2018-01-02
# 31444  Tennessee    Davidson       Nashville  2018-01-02
# 10544  Tennessee  Montgomery     Clarksville  2018-01-02
# 24802  Tennessee      Putnam      Cookeville  2018-01-02
# 37392  Tennessee      McMinn          Athens  2018-01-02
# 29332  Tennessee        Knox       Knoxville  2018-01-02
# 26568  Tennessee     Madison         Jackson  2018-01-02
# 32987  Tennessee      Loudon          Loudon  2018-01-02
# 12316  Tennessee      Sumner  Hendersonville  2018-01-02
# 19349  Tennessee    Hamilton     Chattanooga  2018-01-02
# 15778  Tennessee    Lawrence         Loretto  2018-01-02
# 469    Tennessee       Maury        Columbia  2018-01-02
# 34784  Tennessee      Loudon          Loudon  2018-01-02
# 17547  Tennessee      Blount       Maryville  2018-01-02
# 13990  Tennessee    Sullivan       Kingsport  2018-01-02
# 31445  Tennessee    Davidson       Nashville  2018-01-03
# 29333  Tennessee        Knox       Knoxville  2018-01-03
# 10545  Tennessee  Montgomery     Clarksville  2018-01-03
# 470    Tennessee       Maury        Columbia  2018-01-03
# 2140   Tennessee        Dyer       Dyersburg  2018-01-03
# 19350  Tennessee    Hamilton     Chattanooga  2018-01-03
# 15779  Tennessee    Lawrence         Loretto  2018-01-03
# 26569  Tennessee     Madison         Jackson  2018-01-03
# 37393  Tennessee      McMinn          Athens  2018-01-03
# 22544  Tennessee       Roane        Harriman  2018-01-03
# 17548  Tennessee      Blount       Maryville  2018-01-03
# 32988  Tennessee      Loudon          Loudon  2018-01-03
# 34785  Tennessee      Loudon          Loudon  2018-01-03
# 24803  Tennessee      Putnam      Cookeville  2018-01-03
# 12317  Tennessee      Sumner  Hendersonville  2018-01-03
# 13991  Tennessee    Sullivan       Kingsport  2018-01-03
# 37394  Tennessee      McMinn          Athens  2018-01-04
# 15780  Tennessee    Lawrence         Loretto  2018-01-04
#
#                       parameter sample_duration             units_of_measure  \
# 468    PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 32986  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 17546  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 13989  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 37391  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 19348  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 10543  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 31443  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 12315  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 22542  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 34783  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 2138   PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 24801  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 29331  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 26567  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 15777  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 2139   PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 22543  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 31444  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 10544  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 24802  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 37392  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 29332  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 26568  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 32987  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 12316  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 19349  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 15778  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 469    PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 34784  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 17547  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 13990  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 31445  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 29333  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 10545  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 470    PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 2140   PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 19350  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 15779  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 26569  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 37393  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 22544  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 17548  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 32988  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 34785  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 24803  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 12317  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 13991  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 37394  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 15780  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
#
#        arithmetic_mean   aqi
# 468                5.9  25.0
# 32986              5.5  23.0
# 17546              9.5  40.0
# 13989              5.0  21.0
# 37391              5.9  25.0
# 19348              7.6  32.0
# 10543              7.2  30.0
# 31443              5.1  21.0
# 12315              6.2  26.0
# 22542              5.4  23.0
# 34783              4.7  20.0
# 2138               3.2  13.0
# 24801              6.8  28.0
# 29331              9.3  39.0
# 26567              4.9  20.0
# 15777              6.3  26.0
# 2139               2.4  10.0
# 22543              4.9  20.0
# 31444              3.8  16.0
# 10544              6.1  25.0
# 24802              6.2  26.0
# 37392              6.0  25.0
# 29332             10.0  42.0
# 26568              2.0   8.0
# 32987              5.4  23.0
# 12316              5.6  23.0
# 19349              7.0  29.0
# 15778              5.8  24.0
# 469                7.3  30.0
# 34784              4.1  17.0
# 17547              9.0  38.0
# 13990              7.7  32.0
# 31445              5.0  21.0
# 29333             16.7  61.0
# 10545              6.3  26.0
# 470                6.0  25.0
# 2140               5.2  22.0
# 19350             10.0  42.0
# 15779              3.3  14.0
# 26569              4.1  17.0
# 37393              9.7  40.0
# 22544              5.8  24.0
# 17548             14.5  56.0
# 32988              9.1  38.0
# 34785              5.4  23.0
# 24803              6.3  26.0
# 12317              5.3  22.0
# 13991             11.0  46.0
# 37394              6.3  26.0
# 15780              5.2  22.0

# %%
#Importing Weather Data CSV
weather_df = pd.read_csv('Group data.csv')
weather_df.head()
# Out:
#              City State         Country Date time  Maximum Temperature  \
# 0       Brentwood    TN   United States  1/1/2018                 21.0
# 1    Fayetteville    TN   United States  1/1/2018                 22.0
# 2        Franklin    TN   United States  1/1/2018                 20.7
# 3  Hendersonville    TN   United States  1/1/2018                 21.1
# 4       Nashville    TN   United States  1/1/2018                 21.7
#
#    Minimum Temperature  Temperature  Wind Chill  Heat Index  Precipitation  \
# 0                  6.6         13.2        -7.7         NaN            0.0
# 1                 10.8         14.7        -5.6         NaN            0.0
# 2                  6.6         13.1        -7.4         NaN            0.0
# 3                  6.8         13.3        -7.5         NaN            0.0
# 4                  7.1         13.6        -7.9         NaN            0.0
#
#    Snow  Snow Depth  Wind Speed  Wind Direction  Wind Gust  Visibility  \
# 0   0.0         0.0        13.7          291.50       18.3         9.9
# 1   0.0         0.0        15.6          123.46       22.5         9.7
# 2   0.0         0.0        13.8          306.21       18.3         9.9
# 3   0.0         0.0        13.4          292.13       19.7         9.9
# 4   0.0         0.0        13.9          278.04       21.9         9.9
#
#    Cloud Cover  Relative Humidity        Conditions
# 0         27.4              58.76  Partially cloudy
# 1         32.5              62.40  Partially cloudy
# 2         26.5              59.63  Partially cloudy
# 3         32.2              58.99  Partially cloudy
# 4         32.1              57.18  Partially cloudy

# %%
#Changing format of Datetime to match Pollutant data
weather_df['Date time'] = pd.to_datetime(weather_df['Date time'])
weather_df['Date time'] = weather_df['Date time'].dt.strftime('%Y-%m-%d')
#Sorting weather_df by date
weather_df = weather_df.sort_values(by=['Date time'])
weather_df.head(50)
# Out:
#               City State         Country   Date time  Maximum Temperature  \
# 0        Brentwood    TN   United States  2018-01-01                 21.0
# 1     Fayetteville    TN   United States  2018-01-01                 22.0
# 2         Franklin    TN   United States  2018-01-01                 20.7
# 3   Hendersonville    TN   United States  2018-01-01                 21.1
# 4        Nashville    TN   United States  2018-01-01                 21.7
# 5        Brentwood    TN   United States  2018-01-02                 25.4
# 6     Fayetteville    TN   United States  2018-01-02                 28.7
# 7         Franklin    TN   United States  2018-01-02                 25.1
# 8   Hendersonville    TN   United States  2018-01-02                 25.0
# 9        Nashville    TN   United States  2018-01-02                 25.8
# 14       Nashville    TN   United States  2018-01-03                 35.0
# 13  Hendersonville    TN   United States  2018-01-03                 34.6
# 10       Brentwood    TN   United States  2018-01-03                 34.7
# 11    Fayetteville    TN   United States  2018-01-03                 34.6
# 12        Franklin    TN   United States  2018-01-03                 34.6
# 15       Brentwood    TN   United States  2018-01-04                 23.0
# 16    Fayetteville    TN   United States  2018-01-04                 25.1
# 17        Franklin    TN   United States  2018-01-04                 23.0
# 18  Hendersonville    TN   United States  2018-01-04                 22.5
# 19       Nashville    TN   United States  2018-01-04                 22.9
# 24       Nashville    TN   United States  2018-01-05                 30.5
# 23  Hendersonville    TN   United States  2018-01-05                 29.3
# 20       Brentwood    TN   United States  2018-01-05                 29.8
# 21    Fayetteville    TN   United States  2018-01-05                 31.5
# 22        Franklin    TN   United States  2018-01-05                 29.5
# 25       Brentwood    TN   United States  2018-01-06                 29.3
# 26    Fayetteville    TN   United States  2018-01-06                 32.3
# 27        Franklin    TN   United States  2018-01-06                 29.1
# 28  Hendersonville    TN   United States  2018-01-06                 29.0
# 29       Nashville    TN   United States  2018-01-06                 29.8
# 34       Nashville    TN   United States  2018-01-07                 46.0
# 33  Hendersonville    TN   United States  2018-01-07                 45.4
# 32        Franklin    TN   United States  2018-01-07                 45.3
# 30       Brentwood    TN   United States  2018-01-07                 45.5
# 31    Fayetteville    TN   United States  2018-01-07                 42.4
# 35       Brentwood    TN   United States  2018-01-08                 42.1
# 36    Fayetteville    TN   United States  2018-01-08                 42.8
# 37        Franklin    TN   United States  2018-01-08                 41.8
# 38  Hendersonville    TN   United States  2018-01-08                 42.3
# 39       Nashville    TN   United States  2018-01-08                 42.8
# 44       Nashville    TN   United States  2018-01-09                 49.0
# 42        Franklin    TN   United States  2018-01-09                 48.3
# 43  Hendersonville    TN   United States  2018-01-09                 48.8
# 40       Brentwood    TN   United States  2018-01-09                 48.3
# 41    Fayetteville    TN   United States  2018-01-09                 54.7
# 45       Brentwood    TN   United States  2018-01-10                 64.8
# 46    Fayetteville    TN   United States  2018-01-10                 64.0
# 47        Franklin    TN   United States  2018-01-10                 64.8
# 48  Hendersonville    TN   United States  2018-01-10                 64.9
# 49       Nashville    TN   United States  2018-01-10                 65.1
#
#     Minimum Temperature  Temperature  Wind Chill  Heat Index  Precipitation  \
# 0                   6.6         13.2        -7.7         NaN           0.00
# 1                  10.8         14.7        -5.6         NaN           0.00
# 2                   6.6         13.1        -7.4         NaN           0.00
# 3                   6.8         13.3        -7.5         NaN           0.00
# 4                   7.1         13.6        -7.9         NaN           0.00
# 5                   4.3         14.1        -6.4         NaN           0.00
# 6                   5.7         16.2        -6.0         NaN           0.00
# 7                   4.0         13.8        -6.4         NaN           0.00
# 8                   4.3         13.9        -6.8         NaN           0.00
# 9                   4.8         14.6        -6.9         NaN           0.00
# 14                 16.9         25.1        11.1         NaN           0.00
# 13                 16.4         24.5         9.9         NaN           0.01
# 10                 16.5         24.5        10.9         NaN           0.01
# 11                 17.7         24.4        13.7         NaN           0.00
# 12                 16.3         24.2        10.8         NaN           0.01
# 15                 11.5         17.5        -3.2         NaN           0.00
# 16                 12.7         18.4         1.6         NaN           0.00
# 17                 11.4         17.2        -3.5         NaN           0.00
# 18                 11.5         17.5        -3.2         NaN           0.00
# 19                 11.9         18.1        -2.4         NaN           0.00
# 24                 15.6         22.6         8.2         NaN           0.00
# 23                 14.6         21.8         7.2         NaN           0.00
# 20                 14.2         22.0         7.1         NaN           0.00
# 21                 12.4         20.8        13.4         NaN           0.00
# 22                 13.6         21.8         6.5         NaN           0.00
# 25                 12.0         20.5         2.6         NaN           0.00
# 26                 14.7         22.4         6.3         NaN           0.00
# 27                 11.7         20.3         2.3         NaN           0.00
# 28                 11.6         19.8         3.3         NaN           0.00
# 29                 12.6         20.7         3.5         NaN           0.00
# 34                 16.5         32.3        10.0         NaN           0.00
# 33                 15.4         31.8        10.3         NaN           0.00
# 32                 15.9         31.7        13.3         NaN           0.00
# 30                 16.3         32.0        11.8         NaN           0.00
# 31                 18.1         32.3        12.5         NaN           0.00
# 35                 37.0         40.2        28.4         NaN           0.33
# 36                 33.6         39.4        24.5         NaN           0.82
# 37                 36.9         40.1        28.6         NaN           0.33
# 38                 36.4         40.0        27.3         NaN           0.30
# 39                 37.0         40.4        27.4         NaN           0.31
# 44                 39.7         44.5        37.7         NaN           0.01
# 42                 39.4         43.9        38.1         NaN           0.02
# 43                 39.3         44.1        37.4         NaN           0.02
# 40                 39.5         44.1        38.4         NaN           0.02
# 41                 40.9         47.7        39.9         NaN           0.04
# 45                 40.2         54.3        38.5         NaN           0.00
# 46                 46.6         56.9        43.5         NaN           0.00
# 47                 39.5         53.9        40.5         NaN           0.00
# 48                 41.2         54.8        38.6         NaN           0.00
# 49                 41.7         55.2        38.3         NaN           0.00
#
#     Snow  Snow Depth  Wind Speed  Wind Direction  Wind Gust  Visibility  \
# 0    0.0         0.0        13.7          291.50       18.3         9.9
# 1    0.0         0.0        15.6          123.46       22.5         9.7
# 2    0.0         0.0        13.8          306.21       18.3         9.9
# 3    0.0         0.0        13.4          292.13       19.7         9.9
# 4    0.0         0.0        13.9          278.04       21.9         9.9
# 5    0.0         0.0         7.4          165.92        NaN         9.9
# 6    0.0         0.0         9.3          184.46        NaN         9.9
# 7    0.0         0.0         7.3          193.88        NaN         9.9
# 8    0.0         0.0         7.9          166.08        NaN         9.9
# 9    0.0         0.0         8.8          153.88        NaN         9.9
# 14   0.0         0.0        11.7          240.04       24.2         9.9
# 13   0.0         0.0        11.9          252.83       24.2         9.9
# 10   0.0         0.0        11.2          234.63       24.2         9.9
# 11   0.0         0.0         9.8          246.33       15.0         9.9
# 12   0.0         0.0        11.5          232.00       24.2         9.9
# 15   0.0         0.0        14.5          328.92       23.0         9.9
# 16   0.0         0.0        13.2          330.67       21.8         9.9
# 17   0.0         0.0        14.1          327.21       23.0         9.9
# 18   0.0         0.0        13.2          331.04       20.8         9.9
# 19   0.0         0.0        14.4          333.42       20.8         9.9
# 24   0.0         0.0         9.1          187.83       12.8         9.9
# 23   0.0         0.0         8.3          204.46       12.8         9.9
# 20   0.0         0.0         9.2          210.35       18.3         9.9
# 21   0.0         0.0         8.8          220.67       11.4         9.9
# 22   0.0         0.0         9.5          211.61       18.3         9.9
# 25   0.0         0.0         9.5           56.57        NaN         9.9
# 26   0.0         0.0         7.7           77.63       13.9         9.9
# 27   0.0         0.0         9.6           69.17        NaN         9.9
# 28   0.0         0.0         7.9           83.08        NaN         9.9
# 29   0.0         0.0         9.0          101.71       13.9         9.9
# 34   0.0         0.0        19.0          148.75       29.6         9.9
# 33   0.0         0.0        17.9          144.46       29.8         9.9
# 32   0.0         0.0        16.5          130.88       29.8         9.9
# 30   0.0         0.0        17.3          136.67       29.8         9.9
# 31   0.0         0.0        14.6          127.71       20.6         9.9
# 35   0.0         0.0        15.9          107.04       22.0         5.3
# 36   0.0         0.0        12.7          105.79       21.9         7.0
# 37   0.0         0.0        15.4          105.00       21.8         5.3
# 38   0.0         0.0        17.0          119.33       26.4         5.3
# 39   0.0         0.0        17.0          109.88       25.2         5.2
# 44   0.0         0.0         6.6           69.04        NaN         2.4
# 42   0.0         0.0         5.1           73.71        NaN         2.9
# 43   0.0         0.0         6.1           64.92        NaN         2.8
# 40   0.0         0.0         5.3           78.75        NaN         2.8
# 41   0.0         0.0         8.5           84.29        NaN         6.9
# 45   0.0         0.0        15.9          125.50       24.2         7.1
# 46   0.0         0.0        16.1          140.75       26.4         9.2
# 47   0.0         0.0        15.4          123.00       24.2         7.0
# 48   0.0         0.0        17.0          139.13       29.8         7.7
# 49   0.0         0.0        17.3          133.21       26.4         7.6
#
#     Cloud Cover  Relative Humidity              Conditions
# 0          27.4              58.76        Partially cloudy
# 1          32.5              62.40        Partially cloudy
# 2          26.5              59.63        Partially cloudy
# 3          32.2              58.99        Partially cloudy
# 4          32.1              57.18        Partially cloudy
# 5          16.4              52.74                   Clear
# 6          14.2              55.45                   Clear
# 7          12.3              53.90                   Clear
# 8          18.0              52.93                   Clear
# 9          24.8              50.71                   Clear
# 14         62.0              48.26        Partially cloudy
# 13         60.1              50.06  Rain, Partially cloudy
# 10         54.2              50.58  Rain, Partially cloudy
# 11         45.6              51.64        Partially cloudy
# 12         50.5              51.72  Rain, Partially cloudy
# 15         31.1              55.87        Partially cloudy
# 16         25.5              60.22        Partially cloudy
# 17         30.5              57.06        Partially cloudy
# 18         34.4              56.51        Partially cloudy
# 19         33.7              54.09        Partially cloudy
# 24         85.6              44.32                Overcast
# 23         84.1              47.48                Overcast
# 20         73.1              47.37        Partially cloudy
# 21         50.4              55.45        Partially cloudy
# 22         69.3              49.00        Partially cloudy
# 25         19.2              47.85                   Clear
# 26         18.6              49.70                   Clear
# 27         16.7              48.52                   Clear
# 28         20.2              49.36                   Clear
# 29         25.3              47.41        Partially cloudy
# 34         72.9              39.04        Partially cloudy
# 33         61.0              40.51        Partially cloudy
# 32         44.4              41.97        Partially cloudy
# 30         52.9              40.85        Partially cloudy
# 31         36.1              37.27        Partially cloudy
# 35         85.3              81.64          Rain, Overcast
# 36         97.4              84.55          Rain, Overcast
# 37         81.8              82.05          Rain, Overcast
# 38         99.9              81.62          Rain, Overcast
# 39        100.0              80.75          Rain, Overcast
# 44         92.5              94.90          Rain, Overcast
# 42         78.6              96.33          Rain, Overcast
# 43         94.8              95.66          Rain, Overcast
# 40         80.5              95.92          Rain, Overcast
# 41         86.1              92.84          Rain, Overcast
# 45         70.6              84.13        Partially cloudy
# 46         76.2              82.98                Overcast
# 47         69.5              84.83        Partially cloudy
# 48         81.8              82.54                Overcast
# 49         79.1              81.72                Overcast

# %%
#Checking number of rows to determine which join to use
#Maybe we should drop heat index and wind chill columns? then we wouldnt have to drop as many null rows
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5480 entries, 0 to 5479
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 5480 non-null   object
#  1   State                5480 non-null   object
#  2   Country              5480 non-null   object
#  3   Date time            5480 non-null   object
#  4   Maximum Temperature  5480 non-null   float64
#  5   Minimum Temperature  5480 non-null   float64
#  6   Temperature          5480 non-null   float64
#  7   Wind Chill           2341 non-null   float64
#  8   Heat Index           2156 non-null   float64
#  9   Precipitation        5480 non-null   float64
#  10  Snow                 5480 non-null   float64
#  11  Snow Depth           5480 non-null   float64
#  12  Wind Speed           5480 non-null   float64
#  13  Wind Direction       5480 non-null   float64
#  14  Wind Gust            4426 non-null   float64
#  15  Visibility           5480 non-null   float64
#  16  Cloud Cover          5480 non-null   float64
#  17  Relative Humidity    5480 non-null   float64
#  18  Conditions           5480 non-null   object
# dtypes: float64(14), object(5)
# memory usage: 856.2+ KB

# %%
#Merging weather and pollutant data
merged_location_df = pd.merge(left=clean_locations_nodups_df, right=weather_df, how='inner', left_on=['city', 'date_local'], right_on=['City', 'Date time'])
merged_location_df.info
# Out:
# <bound method DataFrame.info of           state    county            city  date_local  \
# 0     Tennessee  Davidson       Nashville  2018-01-01
# 1     Tennessee    Sumner  Hendersonville  2018-01-01
# 2     Tennessee  Davidson       Nashville  2018-01-02
# 3     Tennessee    Sumner  Hendersonville  2018-01-02
# 4     Tennessee  Davidson       Nashville  2018-01-03
# ...         ...       ...             ...         ...
# 1667  Tennessee  Davidson       Nashville  2020-12-30
# 1668  Tennessee    Sumner  Hendersonville  2020-12-30
# 1669  Tennessee  Davidson       Nashville  2020-12-31
# 1670  Tennessee  Davidson       Nashville  2020-12-31
# 1671  Tennessee    Sumner  Hendersonville  2020-12-31
#
#                      parameter sample_duration             units_of_measure  \
# 0     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 2     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 3     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 4     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# ...                        ...             ...                          ...
# 1667  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1668  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1669  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1670  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1671  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
#
#       arithmetic_mean   aqi            City State         Country   Date time  \
# 0                 5.1  21.0       Nashville    TN   United States  2018-01-01
# 1                 6.2  26.0  Hendersonville    TN   United States  2018-01-01
# 2                 3.8  16.0       Nashville    TN   United States  2018-01-02
# 3                 5.6  23.0  Hendersonville    TN   United States  2018-01-02
# 4                 5.0  21.0       Nashville    TN   United States  2018-01-03
# ...               ...   ...             ...   ...             ...         ...
# 1667              8.7  36.0       Nashville    TN   United States  2020-12-30
# 1668              7.3  30.0  Hendersonville    TN   United States  2020-12-30
# 1669              3.2  13.0       Nashville    TN   United States  2020-12-31
# 1670              2.2   9.0       Nashville    TN   United States  2020-12-31
# 1671              1.0   4.0  Hendersonville    TN   United States  2020-12-31
#
#       Maximum Temperature  Minimum Temperature  Temperature  Wind Chill  \
# 0                    21.7                  7.1         13.6        -7.9
# 1                    21.1                  6.8         13.3        -7.5
# 2                    25.8                  4.8         14.6        -6.9
# 3                    25.0                  4.3         13.9        -6.8
# 4                    35.0                 16.9         25.1        11.1
# ...                   ...                  ...          ...         ...
# 1667                 66.7                 35.4         56.0        28.9
# 1668                 66.1                 36.2         55.5        30.0
# 1669                 46.3                 39.1         41.6        32.3
# 1670                 46.3                 39.1         41.6        32.3
# 1671                 45.2                 38.6         41.0        31.8
#
#       Heat Index  Precipitation  Snow  Snow Depth  Wind Speed  Wind Direction  \
# 0            NaN           0.00   0.0         0.0        13.9          278.04
# 1            NaN           0.00   0.0         0.0        13.4          292.13
# 2            NaN           0.00   0.0         0.0         8.8          153.88
# 3            NaN           0.00   0.0         0.0         7.9          166.08
# 4            NaN           0.00   0.0         0.0        11.7          240.04
# ...          ...            ...   ...         ...         ...             ...
# 1667         NaN           0.12   0.0         0.0        23.8          170.63
# 1668         NaN           0.25   0.0         0.0        22.1          185.75
# 1669         NaN           0.86   0.0         0.0        17.4          128.83
# 1670         NaN           0.86   0.0         0.0        17.4          128.83
# 1671         NaN           0.90   0.0         0.0        16.8          127.13
#
#       Wind Gust  Visibility  Cloud Cover  Relative Humidity  \
# 0          21.9         9.9         32.1              57.18
# 1          19.7         9.9         32.2              58.99
# 2           NaN         9.9         24.8              50.71
# 3           NaN         9.9         18.0              52.93
# 4          24.2         9.9         62.0              48.26
# ...         ...         ...          ...                ...
# 1667       38.1         9.3         68.3              63.09
# 1668       36.1         9.3         67.1              64.16
# 1669       25.0         7.6         98.8              90.33
# 1670       25.0         7.6         98.8              90.33
# 1671       21.8         7.7         97.0              91.89
#
#                   Conditions
# 0           Partially cloudy
# 1           Partially cloudy
# 2                      Clear
# 3                      Clear
# 4           Partially cloudy
# ...                      ...
# 1667  Rain, Partially cloudy
# 1668  Rain, Partially cloudy
# 1669          Rain, Overcast
# 1670          Rain, Overcast
# 1671          Rain, Overcast
#
# [1672 rows x 28 columns]>

# %%
#Final merged DataFrame
merged_location_df.head(5000)
# Out:
#           state    county            city  date_local  \
# 0     Tennessee  Davidson       Nashville  2018-01-01
# 1     Tennessee    Sumner  Hendersonville  2018-01-01
# 2     Tennessee  Davidson       Nashville  2018-01-02
# 3     Tennessee    Sumner  Hendersonville  2018-01-02
# 4     Tennessee  Davidson       Nashville  2018-01-03
# ...         ...       ...             ...         ...
# 1667  Tennessee  Davidson       Nashville  2020-12-30
# 1668  Tennessee    Sumner  Hendersonville  2020-12-30
# 1669  Tennessee  Davidson       Nashville  2020-12-31
# 1670  Tennessee  Davidson       Nashville  2020-12-31
# 1671  Tennessee    Sumner  Hendersonville  2020-12-31
#
#                      parameter sample_duration             units_of_measure  \
# 0     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 2     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 3     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 4     PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# ...                        ...             ...                          ...
# 1667  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1668  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1669  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1670  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
# 1671  PM2.5 - Local Conditions   24-HR BLK AVG  Micrograms/cubic meter (LC)
#
#       arithmetic_mean   aqi            City State         Country   Date time  \
# 0                 5.1  21.0       Nashville    TN   United States  2018-01-01
# 1                 6.2  26.0  Hendersonville    TN   United States  2018-01-01
# 2                 3.8  16.0       Nashville    TN   United States  2018-01-02
# 3                 5.6  23.0  Hendersonville    TN   United States  2018-01-02
# 4                 5.0  21.0       Nashville    TN   United States  2018-01-03
# ...               ...   ...             ...   ...             ...         ...
# 1667              8.7  36.0       Nashville    TN   United States  2020-12-30
# 1668              7.3  30.0  Hendersonville    TN   United States  2020-12-30
# 1669              3.2  13.0       Nashville    TN   United States  2020-12-31
# 1670              2.2   9.0       Nashville    TN   United States  2020-12-31
# 1671              1.0   4.0  Hendersonville    TN   United States  2020-12-31
#
#       Maximum Temperature  Minimum Temperature  Temperature  Wind Chill  \
# 0                    21.7                  7.1         13.6        -7.9
# 1                    21.1                  6.8         13.3        -7.5
# 2                    25.8                  4.8         14.6        -6.9
# 3                    25.0                  4.3         13.9        -6.8
# 4                    35.0                 16.9         25.1        11.1
# ...                   ...                  ...          ...         ...
# 1667                 66.7                 35.4         56.0        28.9
# 1668                 66.1                 36.2         55.5        30.0
# 1669                 46.3                 39.1         41.6        32.3
# 1670                 46.3                 39.1         41.6        32.3
# 1671                 45.2                 38.6         41.0        31.8
#
#       Heat Index  Precipitation  Snow  Snow Depth  Wind Speed  Wind Direction  \
# 0            NaN           0.00   0.0         0.0        13.9          278.04
# 1            NaN           0.00   0.0         0.0        13.4          292.13
# 2            NaN           0.00   0.0         0.0         8.8          153.88
# 3            NaN           0.00   0.0         0.0         7.9          166.08
# 4            NaN           0.00   0.0         0.0        11.7          240.04
# ...          ...            ...   ...         ...         ...             ...
# 1667         NaN           0.12   0.0         0.0        23.8          170.63
# 1668         NaN           0.25   0.0         0.0        22.1          185.75
# 1669         NaN           0.86   0.0         0.0        17.4          128.83
# 1670         NaN           0.86   0.0         0.0        17.4          128.83
# 1671         NaN           0.90   0.0         0.0        16.8          127.13
#
#       Wind Gust  Visibility  Cloud Cover  Relative Humidity  \
# 0          21.9         9.9         32.1              57.18
# 1          19.7         9.9         32.2              58.99
# 2           NaN         9.9         24.8              50.71
# 3           NaN         9.9         18.0              52.93
# 4          24.2         9.9         62.0              48.26
# ...         ...         ...          ...                ...
# 1667       38.1         9.3         68.3              63.09
# 1668       36.1         9.3         67.1              64.16
# 1669       25.0         7.6         98.8              90.33
# 1670       25.0         7.6         98.8              90.33
# 1671       21.8         7.7         97.0              91.89
#
#                   Conditions
# 0           Partially cloudy
# 1           Partially cloudy
# 2                      Clear
# 3                      Clear
# 4           Partially cloudy
# ...                      ...
# 1667  Rain, Partially cloudy
# 1668  Rain, Partially cloudy
# 1669          Rain, Overcast
# 1670          Rain, Overcast
# 1671          Rain, Overcast
#
# [1672 rows x 28 columns]

# %%
pd.options.display.max_columns = None

# %%
#Export to CSV
merged_location_df.to_csv('AirQualityAndWeatherDataMerged.csv')
