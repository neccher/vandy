# %%
import pandas as pd
from aqs_class import AQSFetcher
import matplotlib.pyplot as plt
from config import aqs_key, aqs_email

# %%
aqs_fetcher = AQSFetcher(aqs_email, aqs_key)

# %%
aqi_pollutant_parameters = aqs_fetcher.get_parameter_list_by_class('AQI POLLUTANTS')
aqi_pollutant_parameters
# Out:
#     code                   parameter_description
# 0  42101                         Carbon monoxide
# 1  42401                          Sulfur dioxide
# 2  42602                  Nitrogen dioxide (NO2)
# 3  44201                                   Ozone
# 4  81102                   PM10 Total 0-10um STP
# 5  88101                PM2.5 - Local Conditions
# 6  88502  Acceptable PM2.5 AQI & Speciation Mass

# %%
pollutant_codes = ['44201', '42101', '88101']
#pollutant_codes = aqi_pollutant_parameters['code'].tolist()
print(pollutant_codes)
# Out:
# ['44201', '42101', '88101']

# %%
pollutant_codes[0]
# Out:
# '44201'

# %%
tn_daily_pollutant_data = aqs_fetcher.daily_data_by_state(tn_state_code, pollutant_codes, 20150101, 20151201)
tn_daily_pollutant_data.head(10)
# Out:
#   state_code county_code site_number parameter_code  poc  latitude  longitude  \
# 0         47         037        0040          42101    1   36.1424   -86.7341
# 1         47         037        0040          42101    1   36.1424   -86.7341
# 2         47         037        0040          42101    1   36.1424   -86.7341
# 3         47         037        0040          42101    1   36.1424   -86.7341
# 4         47         037        0040          42101    1   36.1424   -86.7341
# 5         47         037        0040          42101    1   36.1424   -86.7341
# 6         47         037        0040          42101    1   36.1424   -86.7341
# 7         47         037        0040          42101    1   36.1424   -86.7341
# 8         47         037        0040          42101    1   36.1424   -86.7341
# 9         47         037        0040          42101    1   36.1424   -86.7341
#
#    datum        parameter        sample_duration  ... method_code  \
# 0  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         054
# 1  WGS84  Carbon monoxide                 1 HOUR  ...         054
# 2  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         054
# 3  WGS84  Carbon monoxide                 1 HOUR  ...         054
# 4  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         054
# 5  WGS84  Carbon monoxide                 1 HOUR  ...         054
# 6  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         054
# 7  WGS84  Carbon monoxide                 1 HOUR  ...         054
# 8  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         054
# 9  WGS84  Carbon monoxide                 1 HOUR  ...         054
#
#                                   method local_site_name        site_address  \
# 0  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 1  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 2  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 3  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 4  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 5  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 6  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 7  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 8  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
# 9  INSTRUMENTAL - NONDISPERSIVE INFRARED       Near Road  1113 Elm Hill Pike
#
#        state    county                            city  cbsa_code  \
# 0  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 1  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 2  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 3  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 4  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 5  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 6  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 7  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 8  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
# 9  Tennessee  Davidson  Nashville-Davidson (Remainder)      34980
#
#                                              cbsa  date_of_last_change
# 0  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 1  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 2  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 3  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 4  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 5  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 6  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 7  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 8  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
# 9  Nashville-Davidson--Murfreesboro--Franklin, TN           2016-04-07
#
# [10 rows x 31 columns]

# %%
#tn_daily_co_data.columns
tn_daily_pollutant_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45732 entries, 0 to 45731
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state_code           45732 non-null  object
#  1   county_code          45732 non-null  object
#  2   site_number          45732 non-null  object
#  3   parameter_code       45732 non-null  object
#  4   poc                  45732 non-null  int64
#  5   latitude             45732 non-null  float64
#  6   longitude            45732 non-null  float64
#  7   datum                45732 non-null  object
#  8   parameter            45732 non-null  object
#  9   sample_duration      45732 non-null  object
#  10  pollutant_standard   45732 non-null  object
#  11  date_local           45732 non-null  object
#  12  units_of_measure     45732 non-null  object
#  13  event_type           45732 non-null  object
#  14  observation_count    45732 non-null  int64
#  15  observation_percent  45732 non-null  float64
#  16  validity_indicator   45732 non-null  object
#  17  arithmetic_mean      45732 non-null  float64
#  18  first_max_value      45732 non-null  float64
#  19  first_max_hour       45732 non-null  int64
#  20  aqi                  37415 non-null  float64
#  21  method_code          45732 non-null  object
#  22  method               45732 non-null  object
#  23  local_site_name      44392 non-null  object
#  24  site_address         45732 non-null  object
#  25  state                45732 non-null  object
#  26  county               45732 non-null  object
#  27  city                 45732 non-null  object
#  28  cbsa_code            43062 non-null  object
#  29  cbsa                 43062 non-null  object
#  30  date_of_last_change  45732 non-null  object
# dtypes: float64(6), int64(3), object(22)
# memory usage: 10.8+ MB

# %%
tn_daily_pollutant_data['sample_duration'].value_counts()
# Out:
# 8-HR RUN AVG BEGIN HOUR    18026
# 24 HOUR                    17072
# 1 HOUR                      8317
# 8-HR RUN AVG END HOUR       2317
# Name: sample_duration, dtype: int64

# %%
tn_daily_pollutant_data['parameter'].value_counts()
# Out:
# Ozone                       24026
# PM2.5 - Local Conditions    17072
# Carbon monoxide              4634
# Name: parameter, dtype: int64

# %%
tn_daily_pollutant_data = tn_daily_pollutant_data.dropna()

# %%
tn_daily_pollutant_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34744 entries, 0 to 45731
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state_code           34744 non-null  object
#  1   county_code          34744 non-null  object
#  2   site_number          34744 non-null  object
#  3   parameter_code       34744 non-null  object
#  4   poc                  34744 non-null  int64
#  5   latitude             34744 non-null  float64
#  6   longitude            34744 non-null  float64
#  7   datum                34744 non-null  object
#  8   parameter            34744 non-null  object
#  9   sample_duration      34744 non-null  object
#  10  pollutant_standard   34744 non-null  object
#  11  date_local           34744 non-null  object
#  12  units_of_measure     34744 non-null  object
#  13  event_type           34744 non-null  object
#  14  observation_count    34744 non-null  int64
#  15  observation_percent  34744 non-null  float64
#  16  validity_indicator   34744 non-null  object
#  17  arithmetic_mean      34744 non-null  float64
#  18  first_max_value      34744 non-null  float64
#  19  first_max_hour       34744 non-null  int64
#  20  aqi                  34744 non-null  float64
#  21  method_code          34744 non-null  object
#  22  method               34744 non-null  object
#  23  local_site_name      34744 non-null  object
#  24  site_address         34744 non-null  object
#  25  state                34744 non-null  object
#  26  county               34744 non-null  object
#  27  city                 34744 non-null  object
#  28  cbsa_code            34744 non-null  object
#  29  cbsa                 34744 non-null  object
#  30  date_of_last_change  34744 non-null  object
# dtypes: float64(6), int64(3), object(22)
# memory usage: 8.5+ MB

# %%
daily_avg_df['parameter'].value_counts()
# Out:
# PM2.5 - Local Conditions                  17072
# PM10 Total 0-10um STP                       790
# Acceptable PM2.5 AQI & Speciation Mass      110
# Name: parameter, dtype: int64

# %%
eight_hour_df = tn_daily_pollutant_data.loc[tn_daily_co_data['sample_duration']=='24 HOUR']
eight_hour_df.head()
# Out:
#      state_code county_code site_number parameter_code  poc   latitude  \
# 9343         47         065        1011          88101    1  35.233476
# 9344         47         065        1011          88101    1  35.233476
# 9345         47         065        1011          88101    1  35.233476
# 9346         47         065        1011          88101    1  35.233476
# 9347         47         065        1011          88101    1  35.233476
#
#       longitude  datum                 parameter sample_duration  ...  \
# 9343 -85.181581  WGS84  PM2.5 - Local Conditions         24 HOUR  ...
# 9344 -85.181581  WGS84  PM2.5 - Local Conditions         24 HOUR  ...
# 9345 -85.181581  WGS84  PM2.5 - Local Conditions         24 HOUR  ...
# 9346 -85.181581  WGS84  PM2.5 - Local Conditions         24 HOUR  ...
# 9347 -85.181581  WGS84  PM2.5 - Local Conditions         24 HOUR  ...
#
#      method_code                                             method  \
# 9343         145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 9344         145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 9345         145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 9346         145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 9347         145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
#
#               local_site_name                         site_address      state  \
# 9343  Soddy-Daisy High School  SODDY DAISY H.S.  00618 SEQUOYAH RD  Tennessee
# 9344  Soddy-Daisy High School  SODDY DAISY H.S.  00618 SEQUOYAH RD  Tennessee
# 9345  Soddy-Daisy High School  SODDY DAISY H.S.  00618 SEQUOYAH RD  Tennessee
# 9346  Soddy-Daisy High School  SODDY DAISY H.S.  00618 SEQUOYAH RD  Tennessee
# 9347  Soddy-Daisy High School  SODDY DAISY H.S.  00618 SEQUOYAH RD  Tennessee
#
#         county         city  cbsa_code                cbsa  \
# 9343  Hamilton  Soddy-Daisy      16860  Chattanooga, TN-GA
# 9344  Hamilton  Soddy-Daisy      16860  Chattanooga, TN-GA
# 9345  Hamilton  Soddy-Daisy      16860  Chattanooga, TN-GA
# 9346  Hamilton  Soddy-Daisy      16860  Chattanooga, TN-GA
# 9347  Hamilton  Soddy-Daisy      16860  Chattanooga, TN-GA
#
#       date_of_last_change
# 9343           2020-03-04
# 9344           2020-03-04
# 9345           2020-03-04
# 9346           2020-03-04
# 9347           2020-03-04
#
# [5 rows x 31 columns]

# %%
eight_hour_df['parameter'].value_counts()
# Out:
# PM2.5 - Local Conditions                  17072
# PM10 Total 0-10um STP                       790
# Acceptable PM2.5 AQI & Speciation Mass      110
# Name: parameter, dtype: int64

# %%
date_df = tn_daily_pollutant_data.groupby('date_local')
date_df.head(20)
# Out:
#       state_code county_code site_number parameter_code  poc   latitude  \
# 0             47         037        0011          42401    1  36.205055
# 1             47         037        0011          42401    1  36.205055
# 2             47         037        0011          42401    1  36.205055
# 3             47         037        0011          42401    1  36.205055
# 4             47         037        0011          42401    1  36.205055
# ...          ...         ...         ...            ...  ...        ...
# 10882         47         009        0101          44201    1  35.633480
# 10886         47         009        0101          44201    1  35.633480
# 10889         47         009        0101          44201    1  35.633480
# 10890         47         009        0101          44201    1  35.633480
# 10893         47         009        0101          44201    1  35.633480
#
#        longitude  datum       parameter          sample_duration  ...  \
# 0     -86.744720  WGS84  Sulfur dioxide             3-HR BLK AVG  ...
# 1     -86.744720  WGS84  Sulfur dioxide            24-HR BLK AVG  ...
# 2     -86.744720  WGS84  Sulfur dioxide                   1 HOUR  ...
# 3     -86.744720  WGS84  Sulfur dioxide                   1 HOUR  ...
# 4     -86.744720  WGS84  Sulfur dioxide             3-HR BLK AVG  ...
# ...          ...    ...             ...                      ...  ...
# 10882 -83.941606  WGS84           Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 10886 -83.941606  WGS84           Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 10889 -83.941606  WGS84           Ozone                   1 HOUR  ...
# 10890 -83.941606  WGS84           Ozone                   1 HOUR  ...
# 10893 -83.941606  WGS84           Ozone  8-HR RUN AVG BEGIN HOUR  ...
#
#       method_code                             method  \
# 0             060  INSTRUMENTAL - PULSED FLUORESCENT
# 1             060  INSTRUMENTAL - PULSED FLUORESCENT
# 2             060  INSTRUMENTAL - PULSED FLUORESCENT
# 3             060  INSTRUMENTAL - PULSED FLUORESCENT
# 4             060  INSTRUMENTAL - PULSED FLUORESCENT
# ...           ...                                ...
# 10882         047        INSTRUMENTAL - ULTRA VIOLET
# 10886         047        INSTRUMENTAL - ULTRA VIOLET
# 10889         047        INSTRUMENTAL - ULTRA VIOLET
# 10890         047        INSTRUMENTAL - ULTRA VIOLET
# 10893         047        INSTRUMENTAL - ULTRA VIOLET
#
#                             local_site_name  \
# 0                               East Health
# 1                               East Health
# 2                               East Health
# 3                               East Health
# 4                               East Health
# ...                                     ...
# 10882  Great Smoky Mountains NP - Look Rock
# 10886  Great Smoky Mountains NP - Look Rock
# 10889  Great Smoky Mountains NP - Look Rock
# 10890  Great Smoky Mountains NP - Look Rock
# 10893  Great Smoky Mountains NP - Look Rock
#
#                              site_address      state    county           city  \
# 0                       1015 TRINITY LANE  Tennessee  Davidson      Nashville
# 1                       1015 TRINITY LANE  Tennessee  Davidson      Nashville
# 2                       1015 TRINITY LANE  Tennessee  Davidson      Nashville
# 3                       1015 TRINITY LANE  Tennessee  Davidson      Nashville
# 4                       1015 TRINITY LANE  Tennessee  Davidson      Nashville
# ...                                   ...        ...       ...            ...
# 10882  GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee    Blount  Not in a city
# 10886  GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee    Blount  Not in a city
# 10889  GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee    Blount  Not in a city
# 10890  GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee    Blount  Not in a city
# 10893  GREAT SMOKY MOUNTAINS NP LOOK ROCK  Tennessee    Blount  Not in a city
#
#        cbsa_code                                            cbsa  \
# 0          34980  Nashville-Davidson--Murfreesboro--Franklin, TN
# 1          34980  Nashville-Davidson--Murfreesboro--Franklin, TN
# 2          34980  Nashville-Davidson--Murfreesboro--Franklin, TN
# 3          34980  Nashville-Davidson--Murfreesboro--Franklin, TN
# 4          34980  Nashville-Davidson--Murfreesboro--Franklin, TN
# ...          ...                                             ...
# 10882      28940                                   Knoxville, TN
# 10886      28940                                   Knoxville, TN
# 10889      28940                                   Knoxville, TN
# 10890      28940                                   Knoxville, TN
# 10893      28940                                   Knoxville, TN
#
#        date_of_last_change
# 0               2016-02-02
# 1               2016-02-02
# 2               2016-02-02
# 3               2016-02-02
# 4               2016-02-02
# ...                    ...
# 10882           2018-07-19
# 10886           2018-07-19
# 10889           2018-07-19
# 10890           2018-07-19
# 10893           2018-07-19
#
# [6700 rows x 31 columns]

# %%
tn_daily_pollutant_data['city'].value_counts()
# Out:
# Not in a city                     15296
# Memphis                            8874
# Nashville                          7448
# Knoxville                          5239
# Kingsport                          4060
# Oak Ridge                          2618
# Chattanooga                        1859
# Hendersonville                     1835
# Loudon                             1406
# Clarksville                        1308
# Nashville-Davidson (Remainder)     1300
# Soddy-Daisy                        1219
# New Market                          983
# Bloomingdale                        983
# Millington                          979
# Mascot                              979
# Fairview                            978
# Jackson                             764
# Harriman                            440
# Cookeville                          432
# East Ridge                          432
# Maryville                           424
# Loretto                             408
# Dyersburg                           404
# Athens                              404
# Columbia                            352
# Rockwood                            152
# Name: city, dtype: int64

# %%
tn_daily_pollutant_data['county'].value_counts()
# Out:
# Shelby        9853
# Davidson      8748
# Knox          6218
# Sullivan      6018
# Blount        5516
# Montgomery    4061
# Hamilton      3510
# Anderson      2618
# Sevier        2043
# Sumner        1835
# Loudon        1406
# Claiborne     1340
# DeKalb        1330
# Wilson         983
# Jefferson      983
# Williamson     978
# Union          780
# Madison        764
# Roane          592
# Putnam         432
# Lawrence       408
# McMinn         404
# Dyer           404
# Maury          352
# Name: county, dtype: int64

# %%
# Out:
# Bad URL!
